# %%
print("U1.A1")
# Out:
# U1.A1

# %%
#1. primeira aula pratica

# %%
print("olá,mundo!")
# Out:
# olá,mundo!

# %%
#2. criando novas variaveis

# %%
x=10
nome='tony'
nota=8.75
fez_inscrição ='true'

# %%
print(x)
print(nome)
print(nota)
print(fez_inscrição)
# Out:
# 10
# tony
# 8.75
# true

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscrição))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'str'>

# %%
nome = input("digite seu nome:")
# Out:
# digite seu nome: tony

# %%
print(f"olá {'nome'},bem vindo a uma nova disciplina de programação")
# Out:
# olá nome,bem vindo a uma nova disciplina de programação

# %%
nota_1 = int(input('DIGITE A NOTA : '))
nota_2 = int(input('DIGITE A NOTA : '))
nota_3 = int(input('DIGITE A NOTA : '))
nota_4 = int(input('DIGITE A NOTA : '))
# Out:
# DIGITE A NOTA : 5
# DIGITE A NOTA : 6
# DIGITE A NOTA : 7
# DIGITE A NOTA : 8

# %%
media = (nota_1+nota_2+nota_3+nota_4)/4

# %%
print(media)
# Out:
# 6.5

# %%
 if media >= 6:
     situacao = 'aprovado'
 else:
      situacao = 'reprovado'

# %%
print (situacao)
# Out:
# aprovado
