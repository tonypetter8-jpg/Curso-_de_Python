# %%
## U1-A2

# %%
## guardando informações:
idade = 20
e_maior_de_idade = idade >= 18
print(e_maior_de_idade)
# Out:
# True

# %%
idade = int(input('Digite Sua Idade :'))
if idade <= 17:
  print ('Menor de Idade')
elif idade >= 18 and idade < 65:
  print  ('Adulto')
else:
  print ('Idoso')
# Out:
# Digite Sua Idade :45
# Adulto

# %%
idade = int(input('Digite sua idade :'))
if idade < 12:
  print (" Recomendamos o filme infantil: 1.")
elif idade >= 12 and idade < 18:
  print (' Recomendamos o filme infantil: 2.')
else :
  print (' reomendamos o filme: 3.')
# Out:
# Digite sua idade :17
#  Recomendamos o filme infantil: 2.

# %%
ingresso = int(input('quantos ingressos deseja?'))
ingresso_disponiveis =10
if ingresso >0  and ingresso <=10:
  print ('compra realizada com sucesso!')
# Out:
# quantos ingressos deseja?3
# compra realizada com sucesso!

# %%
idade = int(input('Digite sua idade :'))
ingressos_disponiveis =10
if ingressos_disponiveis > 0:
  quantidade_desejada = int(input('Quantos infressos deseja comprar?'))
if idade < 12 and ingresso >= 2 or ingresso >= 1 and ingresso <=10:
  print (" Recomendamos o filme infantil: 1.")
elif idade >= 12 and idade < 18 or ingresso >=2:
  print (' Recomendamos o filme infantil: 2.')
else :
  print (' reomendamos o filme: 3.')
# Out:
# Digite sua idade :14
# Quantos infressos deseja comprar?3
#  Recomendamos o filme infantil: 1.
